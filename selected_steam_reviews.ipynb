# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/My Drive/ml-syst-recommend/steam_reviews.csv')

# %%
steam_review.head()
# Out:
#   date_posted  funny  helpful  hour_played  is_early_access_review  \
# 0  2019-02-10      2        4          578                   False
# 1  2019-02-10      0        0          184                   False
# 2  2019-02-07      0        0          892                   False
# 3  2018-06-14    126     1086          676                   False
# 4  2017-06-20     85     2139          612                   False
#
#   recommendation                                             review  \
# 0    Recommended  &gt Played as German Reich&gt Declare war on B...
# 1    Recommended                                               yes.
# 2    Recommended  Very good game although a bit overpriced in my...
# 3    Recommended  Out of all the reviews I wrote This one is pro...
# 4    Recommended  Disclaimer I survivor main. I play games for f...
#
#                                          title
# 0  Expansion - Hearts of Iron IV: Man the Guns
# 1  Expansion - Hearts of Iron IV: Man the Guns
# ...

# %%
df.isnull().sum()
# Out:
# date_posted                  0
# funny                        0
# helpful                      0
# hour_played                  0
# is_early_access_review       0
# recommendation               0
# review                    1516
# title                        0
# dtype: int64

# %%
steam_review = df.dropna()

# %%
steam_review.isnull().sum()
# Out:
# date_posted               0
# funny                     0
# helpful                   0
# hour_played               0
# is_early_access_review    0
# recommendation            0
# review                    0
# title                     0
# dtype: int64

# %%
# Selected 5000 samples
selected_data = 5000
review_sample = steam_review['review'].sample(n=selected_data, random_state=42)

# %%
df_review = pd.DataFrame({'review': review_sample})

# %%
file_csv = 'steam_review.csv'
df_review.to_csv(file_csv, index=False)

# %%
files.download(file_csv)
